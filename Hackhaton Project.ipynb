# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import gzip
import csv

# %%
path1 = 'https://storage.googleapis.com/data-analyst-interview/plays_sampling_01/part-00000-0dd5f001-57d7-4ec1-a3f0-53ea28bba9c3-c000.csv.gz'
path10 = 'https://storage.googleapis.com/data-analyst-interview/plays_sampling_07/part-00000-4803092d-32ab-4912-b2ba-d37dd93537a2-c000.csv.gz'

# %%
df1_chunks = pd.read_csv(path1, compression = 'gzip', error_bad_lines = False, chunksize = 20000)
df10_chunks = pd.read_csv(path10, compression = 'gzip', error_bad_lines = False, chunksize = 20000)

# %%
df1 = pd.concat(df1_chunks)
df10 = pd.concat(df10_chunks)
# Out:
# b'Skipping line 23509: expected 41 fields, saw 43\n'
# b'Skipping line 36946: expected 41 fields, saw 42\n'
# D:\Data_Science_Files\lib\site-packages\IPython\core\interactiveshell.py:3437: DtypeWarning: Columns (18,19,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# b'Skipping line 43788: expected 41 fields, saw 42\nSkipping line 45437: expected 41 fields, saw 49\nSkipping line 52141: expected 41 fields, saw 42\n'
# b'Skipping line 73470: expected 41 fields, saw 42\nSkipping line 75103: expected 41 fields, saw 42\n'
# D:\Data_Science_Files\lib\site-packages\IPython\core\interactiveshell.py:3437: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# b'Skipping line 87928: expected 41 fields, saw 42\n'
# ...

# %%
df10.shape
# Out:
# (742582, 41)

# %%
df10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742582 entries, 0 to 742581
# Data columns (total 41 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   hash_content_id    742582 non-null  object
#  1   hash_play_id       742582 non-null  object
#  2   hash_visit_id      742582 non-null  object
#  3   hash_watcher_id    742582 non-null  object
#  4   hash_film_id       40525 non-null   object
#  5   hash_event_id      742582 non-null  object
#  6   is_login           742582 non-null  bool
#  7   playback_location  742582 non-null  object
#  8   platform           742582 non-null  object
#  9   play_time          742582 non-null  object
#  10  end_time           742582 non-null  object
#  11  referrer           702119 non-null  object
#  12  average_bitrate    707495 non-null  float64
#  13  bitrate_range      742582 non-null  object
#  14  total_bytes        742582 non-null  int64
# ...

# %%
d10 = list(df10.columns)
df10.head()
# Out:
#                                      hash_content_id  \
# 0  003f6dad4ab48a4e39ea262b19e3b42a4b53c2175078b3...
# 1  0079c67ae8c7f6cbd44768f1988196c137326f3058d995...
# 2  0079c67ae8c7f6cbd44768f1988196c137326f3058d995...
# 3  0079c67ae8c7f6cbd44768f1988196c137326f3058d995...
# 4  0079c67ae8c7f6cbd44768f1988196c137326f3058d995...
#
#                                         hash_play_id  \
# 0  515dd4d7af23ae9ef5a2455bc97ee765fe86224ebaca71...
# 1  047f7b21bcb1a57119229958b11abe364ce1a279f8ae00...
# 2  2623b2970635a15f1cf12bf9aa1e4d545135593e6a860c...
# 3  4850defe8308149c097ff7adfe6fbdab1385a4d2ea7038...
# 4  ae0cb715407a6694fb052f4d25b9c87e97ab6ccafdb388...
#
#                                        hash_visit_id  \
# 0  ed8d97adbba52562575973553003d9a13b103bc4693a6c...
# 1  88a404df574ba3c637bb99e94a2e51b16114f5da6f99cd...
# 2  24abc04f114c9cb0c2087568093a909f04b3a567041fff...
# 3  f1279ae82e3c45f7591ad8e43f69a87d7444bf1c4b70b1...
# ...

# %% [markdown]
# # Variable Explainations for df10 dataset.
#
# 1) hash_content_id: content_id watched by play<br>
# 2) hash_play_id: id of the play<br>
# 3) hash_visit_id: session_id of the play<br>
# 4) hash_watcher_id: watcher_id of the play<br>
# 5) hash_film_id: film_id of the play<br>
# 6) hash_event_id: id of the play (deprecated)<br>
# 7) is_login: boolean when user is logged_in when watch<br>
# 8) playback_location: where user play the video (<strong> direct | embed </strong>)<br>
# 9) platform: platform used to play<br>
# 10) play_time: time the play started<br>
# 11) end_time: time the play ended<br>
# 12) referrer: attribution of the play, source of play coming from<br>
# 13) average_bitrate: average bitrate of play<br>
# 14) bitrate_range: bitrate_range set by user to play<br>
# 15) total_bytes: bytes used when play<br>
# 16) buffer_duration: buffer_duration happen while play content<br>
# 17) referrer_group: group of referrer<br>
# 18) completed: boolean which indicate the play is complete<br>
# 19) utm_source: campaign source<br>
# 20) utm_medium: campaign source<br>
# 21) utm_campaign: campaign source<br>
# 22) player_name: engine player_name<br>
# 23) has_ad: indicating the play has ad or not<br>
# 24) flash_version:<br>
# 25) os_name: os_name of device use to play<br>
# 26) os_version: os_version of device use to play<br>
# 27) browser_name: browser name of device use to play<br>
# 28) browser_version: browser version of device use to play<br>
# 29) app_name: app_name used to play<br>
# 30) autoplay: indicating the play is autoplay when watched on certain platform<br>
# 31) is_premium: indicate the content played is a premium content<br>
# 32) app_version: version app being used<br>
# 33) city: city where the watcher_id play content<br>
# 34) play_duration: duration of play<br>
# 35) content_type: content type of content (<strong>livestreaming | vod | catchup</strong>)<br>
# 36) stream_type: when content_type is livestreaming, stream_type is used to categorize the livestream (<strong>EventStream | TVStream | RadioStream</strong>)<br>
# 37) title: title of content<br>
# 38) category_name: category_name of content<br>
# 39) film_title: title of film<br>
# 40) season_name: season_name of film<br>
# 41) genre_name: genre name of film (if the film is available)

# %%
# Non-numerical variables
df10.select_dtypes(exclude = 'number').head()
# Out:
#                                      hash_content_id  \
# 0  003f6dad4ab48a4e39ea262b19e3b42a4b53c2175078b3...
# 1  0079c67ae8c7f6cbd44768f1988196c137326f3058d995...
# 2  0079c67ae8c7f6cbd44768f1988196c137326f3058d995...
# 3  0079c67ae8c7f6cbd44768f1988196c137326f3058d995...
# 4  0079c67ae8c7f6cbd44768f1988196c137326f3058d995...
#
#                                         hash_play_id  \
# 0  515dd4d7af23ae9ef5a2455bc97ee765fe86224ebaca71...
# 1  047f7b21bcb1a57119229958b11abe364ce1a279f8ae00...
# 2  2623b2970635a15f1cf12bf9aa1e4d545135593e6a860c...
# 3  4850defe8308149c097ff7adfe6fbdab1385a4d2ea7038...
# 4  ae0cb715407a6694fb052f4d25b9c87e97ab6ccafdb388...
#
#                                        hash_visit_id  \
# 0  ed8d97adbba52562575973553003d9a13b103bc4693a6c...
# 1  88a404df574ba3c637bb99e94a2e51b16114f5da6f99cd...
# 2  24abc04f114c9cb0c2087568093a909f04b3a567041fff...
# 3  f1279ae82e3c45f7591ad8e43f69a87d7444bf1c4b70b1...
# ...

# %%
# Numerical Variables
df10.select_dtypes()

# %% [markdown]
# # Data cleaning process

# %%
# For 10% plays dataset
df10.isna().sum()
# Out:
# hash_content_id           0
# hash_play_id              0
# hash_visit_id             0
# hash_watcher_id           0
# hash_film_id         702057
# hash_event_id             0
# is_login                  0
# playback_location         0
# platform                  0
# play_time                 0
# end_time                  0
# referrer              40463
# average_bitrate       35087
# bitrate_range             0
# total_bytes               0
# buffer_duration           0
# referrer_group            0
# completed            271020
# utm_source           741797
# utm_medium           741800
# utm_campaign         742250
# player_name           22875
# has_ad                    0
# flash_version        242930
# os_name              235324
# os_version             2734
# browser_name         234709
# browser_version      251508
# app_name                  0
# autoplay             271167
# is_premium                0
# app_version          500902
# city                 742582
# ...

# %%
print(d10[0])
df10.loc[df10[d10[0]] == '0096dafb1049ee942e8e7cbad5abf4a46dc92e3995caacb42f5d3b3cebfd886a']
# Out:
# hash_content_id
#                                           hash_content_id  \
# 12564   0096dafb1049ee942e8e7cbad5abf4a46dc92e3995caac...
# 12565   0096dafb1049ee942e8e7cbad5abf4a46dc92e3995caac...
# 16730   0096dafb1049ee942e8e7cbad5abf4a46dc92e3995caac...
# 16731   0096dafb1049ee942e8e7cbad5abf4a46dc92e3995caac...
# 20889   0096dafb1049ee942e8e7cbad5abf4a46dc92e3995caac...
# 20890   0096dafb1049ee942e8e7cbad5abf4a46dc92e3995caac...
# 20891   0096dafb1049ee942e8e7cbad5abf4a46dc92e3995caac...
# 20892   0096dafb1049ee942e8e7cbad5abf4a46dc92e3995caac...
# 25079   0096dafb1049ee942e8e7cbad5abf4a46dc92e3995caac...
# 25080   0096dafb1049ee942e8e7cbad5abf4a46dc92e3995caac...
# 33349   0096dafb1049ee942e8e7cbad5abf4a46dc92e3995caac...
# 99224   0096dafb1049ee942e8e7cbad5abf4a46dc92e3995caac...
# 99225   0096dafb1049ee942e8e7cbad5abf4a46dc92e3995caac...
# 107676  0096dafb1049ee942e8e7cbad5abf4a46dc92e3995caac...
# 107677  0096dafb1049ee942e8e7cbad5abf4a46dc92e3995caac...
# ...

# %%
len(df10[d10[4]].unique())
# Out:
# 669
